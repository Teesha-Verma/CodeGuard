# %% [markdown]
# # Jupyter Notebook 7 — Benchmark Evaluation
#
# **Purpose:** Execute the automated BenchmarkRunner test suite and visualize precision-recall curves and false-positive dashboards.

# %%
from app.evaluation.benchmark_runner import BenchmarkRunner

runner = BenchmarkRunner()
summary = runner.run_evaluations()
print(f"Precision  : {summary['precision']}")
print(f"Recall     : {summary['recall']}")
print(f"Accuracy   : {summary['accuracy']}")
