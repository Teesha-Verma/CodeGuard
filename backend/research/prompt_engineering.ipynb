# %% [markdown]
# # Jupyter Notebook 5 — Prompt Engineering
#
# **Purpose:** Optimize anchoring system prompts. Verify max-sentence constraints and structured JSON parameters.

# %%
from app.llm.prompts import BUG_DETECTION_SYSTEM_PROMPT

print("BUG DETECTION SYSTEM PROMPT:")
print(BUG_DETECTION_SYSTEM_PROMPT)
