# %% [markdown]
# # Jupyter Notebook 6 — Hallucination Testing
#
# **Purpose:** Feed safe and clean python snippets into the CodeGuard reasoning engine. Verify that the false-positive/hallucination rate remains exactly 0%.

# %%
from app.evaluation.benchmark_runner import TEST_SUITE

safe_cases = [c for c in TEST_SUITE if not c["is_buggy"]]
print(f"Safe cases to evaluate: {len(safe_cases)}")
for c in safe_cases:
    print(f"- Case: {c['name']}")
