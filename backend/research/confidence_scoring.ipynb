# %% [markdown]
# # Jupyter Notebook 8 — Confidence Scoring
#
# **Purpose:** Validate the mathematical weights of the ConfidenceEngine and verify proper score caps.

# %%
from app.reasoning.confidence_engine import ConfidenceEngine

# Sample Case A: Both AST and Linter match
case_a = ConfidenceEngine.calculate(
    finding={"issue": "test"},
    raw_sources=["ast", "bandit"],
    evidence={"ast_nodes": [{}], "linter_rules": [{}]}
)
print("Case A (AST + Linter):", case_a)
