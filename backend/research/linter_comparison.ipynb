# %% [markdown]
# # Jupyter Notebook 4 — Linter Comparison
#
# **Purpose:** Run Pylint, Flake8, and Bandit inside subprocess environments. Compare overlaps and severity mappings.

# %%
import subprocess
import sys

print("PyLint version:")
subprocess.run(["pylint", "--version"])
print("\nFlake8 version:")
subprocess.run(["flake8", "--version"])
print("\nBandit version:")
subprocess.run(["bandit", "--version"])
